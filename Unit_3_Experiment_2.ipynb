# %% [markdown]
# NaN Values in Mathematical Operations

# %%
import numpy as np
import pandas as pd
data={'A':[10,10,np.nan,10,10],'B':[10,np.nan,10,10,10]}
df=pd.DataFrame(data)
df
# Out:
#       A     B
# 0  10.0  10.0
# 1  10.0   NaN
# 2   NaN  10.0
# 3  10.0  10.0
# 4  10.0  10.0

# %%
print("\nsum of column A(default behavior):",df['A'].sum())
#by default nan values will be ignored
print("\nsum of column B(default behavior):",df['B'].sum())
# Out:
# sum of column A(default behavior): 40.0
#
# sum of column B(default behavior): 40.0

# %%
print("Sum of column A(ignoring nan:)",df['A'].sum(skipna=True))
print("Sum of column A(ignoring nan):",df['A'].sum(skipna=False))
# Out:
# Sum of column A(ignoring nan:) 40.0
# Sum of column A(ignoring nan): nan

# %% [markdown]
# Filling in Missing Data

# %%
df_filled=df.fillna(0) #filling nan with constant value 0
print(df_filled)
# Out:
#       A     B
# 0  10.0  10.0
# 1  10.0   0.0
# 2   0.0  10.0
# 3  10.0  10.0
# 4  10.0  10.0

# %%
r=df.fillna(df.mean())
#filling nan with column mean
print("\n DataFrame after filling NaN with column mean:")
print(r)
# Out:
#  DataFrame after filling NaN with column mean:
#       A     B
# 0  10.0  10.0
# 1  10.0  10.0
# 2  10.0  10.0
# 3  10.0  10.0
# 4  10.0  10.0

# %%
df=pd.read_csv(r"/content/Bengaluru_House_Data.csv")
print(df.head())
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
df1=df.fillna({"balcony":1})
df1["balcony"].isnull().sum()
# Out:
# 0

# %%
df=df.fillna({"balcony":1,"price":100," society":"APPLE"})
df["balcony"].isnull().sum()
# Out:
# 0

# %%
#handling numeric attributes
for i in ['balcony']:
  df[i].fillna(df[i].mean(),inplace=True)
df.isnull().sum()
# Out:
# <ipython-input-11-7ce8e373ba0e>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[i].fillna(df[i].mean(),inplace=True)
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony            0
# price              0
# dtype: int64

# %%
for i in ['society']:
  df[i].fillna(df[i].mode(),inplace=True)
# Out:
# <ipython-input-12-e56a24c9cfbb>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[i].fillna(df[i].mode(),inplace=True)

# %% [markdown]
# Forward and Backward filling of missing values

# %%
import numpy as np
import pandas as pd
data={'A':[10,10,np.nan,10,10],'B':[10,np.nan,10,10,10]}
df=pd.DataFrame(data)
df
# Out:
#       A     B
# 0  10.0  10.0
# 1  10.0   NaN
# 2   NaN  10.0
# 3  10.0  10.0
# 4  10.0  10.0

# %%
#Forward Fill(propagates last valid value forward)
df_forward_filled=df.fillna(method='ffill')
print("\nDataFrame after forward fill:")
print(df_forward_filled)
# Out:
# DataFrame after forward fill:
#       A     B
# 0  10.0  10.0
# 1  10.0  10.0
# 2  10.0  10.0
# 3  10.0  10.0
# 4  10.0  10.0
# <ipython-input-14-ef349c4e7e36>:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_forward_filled=df.fillna(method='ffill')

# %%
#Forward Fill(propagates last valid value forward)
df_forward_filled=df.fillna(method='ffill',axis=0)
print("\nDataFrame after forward fill:")
print(df_forward_filled)
# Out:
# DataFrame after forward fill:
#       A     B
# 0  10.0  10.0
# 1  10.0  10.0
# 2  10.0  10.0
# 3  10.0  10.0
# 4  10.0  10.0
# <ipython-input-15-380bacf7aa6a>:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_forward_filled=df.fillna(method='ffill',axis=0)

# %%
#backward Fill(propagates last valid value backward)
df_forward_filled=df.fillna(method='bfill',axis=0)
print("\nDataFrame after forward fill:")
print(df_forward_filled)
# Out:
# DataFrame after forward fill:
#       A     B
# 0  10.0  10.0
# 1  10.0  10.0
# 2  10.0  10.0
# 3  10.0  10.0
# 4  10.0  10.0
# <ipython-input-16-e05391deb9ef>:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_forward_filled=df.fillna(method='bfill',axis=0)

# %%
#backward Fill(propagates last valid value backward)
df_forward_filled=df.fillna(method='bfill',axis=1)
print("\nDataFrame after forward fill:")
print(df_forward_filled)
# Out:
# DataFrame after forward fill:
#       A     B
# 0  10.0  10.0
# 1  10.0   NaN
# 2  10.0  10.0
# 3  10.0  10.0
# 4  10.0  10.0
# <ipython-input-17-019de438a76a>:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_forward_filled=df.fillna(method='bfill',axis=1)

# %%
#Forward Fill(propagates last valid value forward)
df_forward_filled=df.fillna(method='ffill',axis=1)
print("\nDataFrame after forward fill:")
print(df_forward_filled)
# Out:
# DataFrame after forward fill:
#       A     B
# 0  10.0  10.0
# 1  10.0  10.0
# 2   NaN  10.0
# 3  10.0  10.0
# 4  10.0  10.0
# <ipython-input-18-d6b2b4722c87>:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_forward_filled=df.fillna(method='ffill',axis=1)

# %% [markdown]
# Filling with Index values

# %%
import numpy as np
import pandas as pd
data={'A':[10,10,np.nan,10,10],'B':[10,np.nan,10,10,10]}
df=pd.DataFrame(data)
df
# Out:
#       A     B
# 0  10.0  10.0
# 1  10.0   NaN
# 2   NaN  10.0
# 3  10.0  10.0
# 4  10.0  10.0

# %%
index_series=pd.Series(df.index,index=df.index)
print("\nIndex Series:")
print(index_series)
# Out:
# Index Series:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %%
for col in df.columns:
  df[col].fillna(index_series,inplace=True)
df
# Out:
# <ipython-input-21-c1038b85c11d>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(index_series,inplace=True)
#       A     B
# 0  10.0  10.0
# 1  10.0   1.0
# 2   2.0  10.0
# 3  10.0  10.0
# 4  10.0  10.0

# %% [markdown]
#   Interpolation

# %%
import pandas as pd
df=pd.read_csv(r"/content/Bengaluru_House_Data.csv")
df.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
import pandas as pd
df=pd.read_csv(r"/content/Bengaluru_House_Data.csv")
df['bath']=df['bath'].interpolate(method='linear')
df.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath               0
# balcony          609
# price              0
# dtype: int64

# %% [markdown]
# IMPUTER from SKLEARN Package

# %%
dff=df
from sklearn.impute import KNNImputer #Importing Imputer
impute =KNNImputer() #Initializing the Imputer

# %%
for i in df.select_dtypes(include='number').columns:
  df[i]=impute.fit_transform(df[[i]]) #select one or more columns
df.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath               0
# balcony            0
# price              0
# dtype: int64
