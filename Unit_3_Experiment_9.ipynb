# %%
#Demonstration of scaling(Normalization and Standardization)
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler,LabelEncoder
#sample data
data={'Age':[25,30,35,40,45],
      'Income':[50000,60000,70000,80000,90000],
      'Gender':['Male','Female','Female','Male','Male']
      }
df=pd.DataFrame(data)
print(df)
# Out:
#    Age  Income  Gender
# 0   25   50000    Male
# 1   30   60000  Female
# 2   35   70000  Female
# 3   40   80000    Male
# 4   45   90000    Male

# %%
#Normalization
scaler=MinMaxScaler()
df['salary_Normalized']=scaler.fit_transform(df[['Income']])
print(df)
#
# Out:
#    Age  Income  Gender  salary_Normalized
# 0   25   50000    Male               0.00
# 1   30   60000  Female               0.25
# 2   35   70000  Female               0.50
# 3   40   80000    Male               0.75
# 4   45   90000    Male               1.00

# %%
#standardization
scaler=StandardScaler()
df['salary_Normalized']=scaler.fit_transform(df[['Income']])
print(df)
#
# Out:
#    Age  Income  Gender  salary_Normalized
# 0   25   50000    Male          -1.414214
# 1   30   60000  Female          -0.707107
# 2   35   70000  Female           0.000000
# 3   40   80000    Male           0.707107
# 4   45   90000    Male           1.414214

# %%
#Encoding categorical data
encoder=LabelEncoder()
df['Gender_encoded']=encoder.fit_transform(df['Gender'])
df
# Out:
#    Age  Income  Gender  salary_Normalized  Gender_encoded
# 0   25   50000    Male          -1.414214               1
# 1   30   60000  Female          -0.707107               0
# 2   35   70000  Female           0.000000               0
# 3   40   80000    Male           0.707107               1
# 4   45   90000    Male           1.414214               1
